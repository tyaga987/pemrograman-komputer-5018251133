# %% [markdown]
# # Week 2 Assignment
# ## Engineering Unit and Electrical Calculator
# Nama : Tyaga Hijrah Katilu
#
# NRP : 5018251133
#
# Kelas : Pemrograman Komputer (A)

# %%
speed_kmh = float(input("Enter speed [km/h]: "))
speed_ms = speed_kmh / 3.6
print(f"Speed = {speed_ms:.2f} m/s")
# Out:
# Enter speed [km/h]: 5
# Speed = 1.39 m/s

# %%
Power_Kw = float(input("Power (Kw): "))
Power_w = Power_Kw * 1000
print(f"Power = {Power_w:.2f} W")
# Out:
# Power (Kw): 12.5
# Power = 12500.00 W

# %%
Tegangan = float(input("Voltage [V]: "))
Arus = float(input("Arus [A]: "))
power = Tegangan * Arus
print(f"Power = {power:.2f} W")
Waktu = float(input("Waktu [h]: "))
energi = power * Waktu
print(f"Energi = {energi:.2f} Wh")
# Out:
# Voltage [V]: 12
# Arus [A]: 24
# Power = 288.00 W
# Waktu [h]: 48
# Energi = 13824.00 Wh

# %%
voltage = float(input("Voltage [V]: "))
Arus = float(input("Arus [A]: "))
power = voltage * Arus
print(f"Power = {power:.2f} W")
Waktu = float(input("Waktu [h]: "))
energi = power * Waktu
print(f"Energi = {energi:.2f} Wh")

power_limit = 200
voltage_limit = 24

is_high_power = power > power_limit
is_high_voltage = voltage > voltage_limit

print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
# Out:
# Voltage [V]: 12
# Arus [A]: 24
# Power = 288.00 W
# Waktu [h]: 48
# Energi = 13824.00 Wh
# High power : True
# High voltage : False
# Both conditions : False
# Any condition : True

# %% [markdown]
# 1. Apa perbedaan int dan float?
#
#   int digunakan untuk menghitung bilangan bulat sedangkan float digunakan untuk menghitung bilangan desimal
#
# 2. Mengapa hasil input() perlu dikonversi menggunakan float() untuk perhitungan numerik?
#
#   Fungsi input() di Python selalu menghasilkan tipe data string (teks), meskipun pengguna mengetikkan angka. Jika Anda tidak mengonversinya, Python akan memperlakukan angka tersebut sebagai teks biasa.
#
# 3. Apa perbedaan operator = dan == dalam Python?
#
#   = digunakan untuk memasukkan nilai ke dalam sebuah variabel, == digunakan untuk memeriksa apakah 2 bilangan sama atau identik
#
# 4. Apa fungsi operator and dan or?
#
#   and hanya akan menghasilkan true jika 2 pernyataan memenuhi, or akann menghasilkan true jika salah satu pernyataan memenuhi
#
#
# 5. Apa satu kesalahan yang Anda temui saat mengerjakan tugas ini, dan bagaimana Anda memperbaikinya?
#
# salah memasukkan variabel, saya memperbaikinya dengan cara menyamakan variabel yang ada sebelumnya.
